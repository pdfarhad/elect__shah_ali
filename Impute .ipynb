# %%
import sys
print(sys.version)
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# Out:
# 3.5.2 |Anaconda 4.2.0 (x86_64)| (default, Jul  2 2016, 17:52:12)
# [GCC 4.2.1 Compatible Apple LLVM 4.2 (clang-425.0.28)]

# %%
df = pd.read_csv('../ShahAli.csv')
df.head()
# Out:
#        SL                     NAME  ACCOUNT_NO METER_NO  \
# 0  5702.0  PAIKPARA GOVT STAFF QTR    29000041  1068554
# 1  5871.0  PAIKPARA GOVT STAFF QTR    29000041  1068554
# 2  5904.0  PAIKPARA GOVT STAFF QTR    29000041  1068554
# 3  5916.0  PAIKPARA GOVT STAFF QTR    29000041  1068554
# 4  6041.0  PAIKPARA GOVT STAFF QTR    29000041  1068554
#
#                     ADDRESS  ZONE  BLOCK  ROUTE  LOAD TARIFF METER_STATUS  \
# 0  BLD-129/10 MIRPUR, DHAKA  SAAA    100   10.0     2      A        Child
# 1  BLD-129/10 MIRPUR, DHAKA  SAAA    100   10.0     2      A        Child
# 2  BLD-129/10 MIRPUR, DHAKA  SAAA    100   10.0     2      A        Child
# 3  BLD-129/10 MIRPUR, DHAKA  SAAA    100   10.0     2      A        Child
# 4  BLD-129/10 MIRPUR, DHAKA  SAAA    100   10.0     2      A        Child
#
#    MONTH  YEAR   UNIT
# 0      6  2001  176.0
# 1      9  2001  200.0
# 2     10  2001  220.0
# 3      8  2001  214.0
# 4     12  2001  149.0

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# SL              0
# NAME            0
# ACCOUNT_NO      0
# METER_NO        0
# ADDRESS         0
# ZONE            0
# BLOCK           0
# ROUTE           0
# LOAD            0
# TARIFF          0
# METER_STATUS    0
# MONTH           0
# YEAR            0
# UNIT            0
# dtype: int64

# %%
df.to_csv('../ShahAli.csv')

# %%
df.UNIT.lt(0).sum()
# Out:
# 10927

# %%
neg_unit_rows = df.loc[df['UNIT'] <0]

# %%
neg_unit_rows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10927 entries, 33543 to 4536941
# Data columns (total 14 columns):
# SL              10927 non-null float64
# NAME            10927 non-null object
# ACCOUNT_NO      10927 non-null int64
# METER_NO        10927 non-null object
# ADDRESS         10927 non-null object
# ZONE            10927 non-null object
# BLOCK           10927 non-null int64
# ROUTE           10927 non-null float64
# LOAD            10927 non-null int64
# TARIFF          10927 non-null object
# METER_STATUS    10927 non-null object
# MONTH           10927 non-null int64
# YEAR            10927 non-null int64
# UNIT            10927 non-null float64
# dtypes: float64(3), int64(5), object(6)
# memory usage: 1.3+ MB

# %%
neg_unit_rows.head()
# Out:
#             SL               NAME  ACCOUNT_NO METER_NO  \
# 33543  20392.0   MD EMDADUL HOQUE    29003601  8120275
# 33758  20693.0  MRS  ALAYA RAHMAN    29003611   032291
# 33775  23312.0  MRS  ALAYA RAHMAN    29003611   032291
# 33776  23468.0  MRS  ALAYA RAHMAN    29003611   032291
# 33786  25110.0  MRS  ALAYA RAHMAN    29003611   032291
#
#                                  ADDRESS  ZONE  BLOCK  ROUTE  LOAD TARIFF  \
# 33543  2/8/I/2 TOLAR BAGH MIRPUR, DHAAK.  SAAA    150  360.0     1      A
# 33758   2 8/1 3   TOLAR BAG MIRPUR DHAKA  SAAA    150  400.0     1      A
# 33775   2 8/1 3   TOLAR BAG MIRPUR DHAKA  SAAA    150  400.0     1      A
# 33776   2 8/1 3   TOLAR BAG MIRPUR DHAKA  SAAA    150  400.0     1      A
# 33786   2 8/1 3   TOLAR BAG MIRPUR DHAKA  SAAA    150  400.0     1      A
#
#       METER_STATUS  MONTH  YEAR   UNIT
# 33543        check     10  2013  -78.0
# 33758        check      1  2014 -189.0
# 33775        check      6  2015   -3.0
# 33776        check      7  2015   -1.0
# 33786        check      5  2016   -1.0

# %% [markdown]
# First we compute the default mean of an individual user

# %%
# def impute(x):
#     x['METER_NO']
# neg_unit_rows['new_unit'] = neg_unit_rows.apply(lambda x: impute(x) if x['UNIT']<0 else x['UNIT'])

# df.groupby(df['METER_NO'],df['YEAR'])
neg_group = df.groupby(['ACCOUNT_NO','YEAR'])
neg_group.UNIT.mean()
# Out:
# ACCOUNT_NO  YEAR
# 15000001    2011     264.000000
#             2012     121.416667
#             2013     157.583333
#             2014     156.916667
#             2015     361.750000
#             2016     406.600000
# 15000002    2011    1013.500000
#             2012     763.750000
#             2013     690.750000
#             2014     166.416667
#             2015     231.833333
#             2016     225.400000
# 15000003    2011     306.833333
#             2012     462.666667
#             2013     544.666667
#             2014     237.000000
#             2015     250.333333
#             2016      94.700000
# 15000004    2011     874.250000
#             2012     510.166667
#             2013     333.083333
#             2014     316.333333
#             2015     383.666667
#             2016     401.200000
# 15000005    2011       0.250000
#             2012       4.083333
#             2013     108.500000
#             2014     144.416667
#             2015     138.333333
#             2016     108.777778
#                        ...
# 31519493    2011       0.875000
#             2012       1.166667
#             2013      51.083333
#             2014      15.083333
#             2015       0.000000
#             2016       0.000000
# 31519503    2011     403.571429
#             2012     295.333333
#             2013     358.916667
#             2014     338.916667
#             2015     296.333333
#             2016     207.600000
# 31519527    2011     237.428571
#             2012     309.833333
#             2013     439.833333
#             2014     567.666667
#             2015     594.916667
#             2016     708.800000
# 31519586    2011      17.000000
#             2012     151.833333
#             2013     117.916667
#             2014     143.083333
#             2015      69.666667
#             2016      81.300000
# 31519587    2011     635.500000
#             2012     460.166667
#             2013     528.833333
#             2014     599.416667
#             2015     545.416667
#             2016     571.600000
# Name: UNIT, dtype: float64

# %% [markdown]
# but there are so many negative values in the columns so it would be confusing,

# %%
neg_group = df.groupby(['ACCOUNT_NO','YEAR'])#.filter(lambda x: x['UNIT'] >0)
neg_group.UNIT.count()
# Out:
# ACCOUNT_NO  YEAR
# 15000001    2011     6
#             2012    12
#             2013    12
#             2014    12
#             2015    12
#             2016    10
# 15000002    2011     4
#             2012    12
#             2013    12
#             2014    12
#             2015    12
#             2016    10
# 15000003    2011     6
#             2012    12
#             2013    12
#             2014    12
#             2015    12
#             2016    10
# 15000004    2011     4
#             2012    12
#             2013    12
#             2014    12
#             2015    12
#             2016    10
# 15000005    2011     4
#             2012    12
#             2013    12
#             2014    12
#             2015    12
#             2016     9
#                     ..
# 31519493    2011     8
#             2012    12
#             2013    12
#             2014    12
#             2015    12
#             2016     2
# 31519503    2011     7
#             2012    12
#             2013    12
#             2014    12
#             2015    12
#             2016    10
# 31519527    2011     7
#             2012    12
#             2013    12
#             2014    12
#             2015    12
#             2016    10
# 31519586    2011     2
#             2012    12
#             2013    12
#             2014    12
#             2015    12
#             2016    10
# 31519587    2011     6
#             2012    12
#             2013    12
#             2014    12
#             2015    12
#             2016    10
# Name: UNIT, dtype: int64

# %% [markdown]
# we need to impute them with the mean value

# %%
neg_group.get_group((31519587,2011))
# Out:
#               SL              NAME  ACCOUNT_NO METER_NO  \
# 4269029  13377.0  MD.ALOMGIR SHEAK    31519587   012922
# 4269030  13489.0  MD.ALOMGIR SHEAK    31519587   012922
# 4269031  13775.0  MD.ALOMGIR SHEAK    31519587   012922
# 4269032  13877.0  MD.ALOMGIR SHEAK    31519587   012922
# 4269033  14015.0  MD.ALOMGIR SHEAK    31519587   012922
# 4269034  14115.0  MD.ALOMGIR SHEAK    31519587   012922
#
#                                                    ADDRESS  ZONE  BLOCK  \
# 4269029  House/Flat # 15, Road # 8, Block # H, Section ...  SAFE    190
# 4269030  House/Flat # 15, Road # 8, Block # H, Section ...  SAFE    190
# 4269031  House/Flat # 15, Road # 8, Block # H, Section ...  SAFE    190
# 4269032  House/Flat # 15, Road # 8, Block # H, Section ...  SAFE    190
# 4269033  House/Flat # 15, Road # 8, Block # H, Section ...  SAFE    190
# 4269034  House/Flat # 15, Road # 8, Block # H, Section ...  SAFE    190
#
#           ROUTE  LOAD TARIFF METER_STATUS  MONTH  YEAR   UNIT
# 4269029  1390.0     2      A       Single      7  2011  780.0
# 4269030  1390.0     2      A       Single      8  2011  780.0
# 4269031  1390.0     2      A       Single      9  2011  782.0
# 4269032  1390.0     2      A       Single     10  2011  677.0
# 4269033  1390.0     2      A       Single     11  2011  548.0
# 4269034  1390.0     2      A       Single     12  2011  246.0
