# %%
import sys 
print(sys.version)
# Out:
# 3.5.2 |Anaconda 4.2.0 (64-bit)| (default, Jul  5 2016, 11:41:13) [MSC v.1900 64 bit (AMD64)]

# %%
import pandas as pd 
import numpy as np
import gmaps
import matplotlib.pyplot as plt

# %%
input_file = pd.read_excel("../tongi_east_Account_wise_consumer.xls")
input_file.head()
# Out:
#    ACCOUNT_NO     METER_NO BILLING_ZONE BLOCK_BILL  ROUTE_NUMBER  \
# 0    23211011  12659411/12           EA        A01          20.0
# 1    23211551  12659211/12           EA        A01          30.0
# 2    23211541  10654706/12           EA        A01          40.0
# 3    23211001  12660011/12           EA        A01          50.0
# 4    23211481       111857           EA        A01          60.0
#
#                                   NAME                              ADDRESS  \
# 0  MANAGER GTPS 80 MW  TONGI MALOTI GR                    GTPS 80 MW TONGI,
# 1                       P.D-80 MW GTPS  800,SFT MALOTI GR FLOOR WEST TONGI,
# 2                       P.D-80 MW GTPS  800,SFT MALOTI FIRST FLOOR EAST, TO
# 3  MANAGER GTPS 80 MW  TONGI MALOTI FI                    GTPS 80 MW TONGI,
# 4   MANAGER GTPS 80 MW  TONGI BELLY GR                    GTPS 80 MW TONGI,
#
#    LOAD SANCTION_TARIFF  UNIT_JAN2010          ...           UNIT_MAY2016  \
# ...

# %%
input_file.isnull().sum()
# Out:
# ACCOUNT_NO                    0
# METER_NO                      0
# BILLING_ZONE                  0
# BLOCK_BILL                    0
# ROUTE_NUMBER                  0
# NAME                          0
# ADDRESS                       1
# LOAD                          0
# SANCTION_TARIFF               0
# UNIT_JAN2010              20724
# READING_DATE_JAN2010      20724
# UNIT_FEB2010              20547
# READING_DATE_FEB2010      20547
# UNIT_MAR2010              20431
# READING_DATE_MAR2010      20431
# UNIT_APRIL2010            20292
# READING_DATE_APRIL2010    20292
# UNIT_MAY2010              20284
# READING_DATE_MAY2010      20284
# UNIT_JUN2010              20277
# READING_DATE_JUN2010      20277
# UNIT_JULY2010             20278
# READING_DATE_JULY2010     20278
# UNIT_AUG2010              20269
# READING_DATE_AUG2010      20269
# UNIT_SEPT2010             20272
# READING_DATE_SEPT2010     20272
# UNIT_OCT2010              20272
# READING_DATE_OCT2010      20272
# ...

# %%
df2 = pd.melt(input_file, id_vars=["ACCOUNT_NO","METER_NO","BILLING_ZONE","BLOCK_BILL","ROUTE_NUMBER","NAME","ADDRESS","LOAD","SANCTION_TARIFF"],var_name="Time",value_name="Unit")
